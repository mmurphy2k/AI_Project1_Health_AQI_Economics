# %%
# Import the required libraries and dependencies
import pandas as pd
import requests
import json
import os

os.makedirs('Resources', exist_ok=True)

# %%
# Setup Variables
sample_url = "https://aqs.epa.gov/data/api/annualData/byState?email=test@aqs.api&key=test&param=45201&bdate=19950515&edate=19950515&state=37"
base_url = "https://aqs.epa.gov/data/api/"
endpoint = "annualData/byState"
email = "scmoujahed@gmail.com"
key = "mauveswift17"
param = "45201"

# %%
# Pull AQI for the state of Washington for the Years 2015-2020
#Washington = 53
#2015
aqi_2015 = pd.DataFrame(requests.get(base_url + endpoint + "?email=" + email + "&key=" + key + "&param=" + param + "&bdate=" + "20150101" + "&edate=" + "20151231" + "&state=" + "53").json()["Data"])
# display(aqi_2015.shape)
#2016
aqi_2016 = pd.DataFrame(requests.get(base_url + endpoint + "?email=" + email + "&key=" + key + "&param=" + param + "&bdate=" + "20160101" + "&edate=" + "20161231" + "&state=" + "53").json()["Data"])
# display(aqi_2016.shape)
#2017
aqi_2017 = pd.DataFrame(requests.get(base_url + endpoint + "?email=" + email + "&key=" + key + "&param=" + param + "&bdate=" + "20170101" + "&edate=" + "20171231" + "&state=" + "53").json()["Data"])
# display(aqi_2017.shape)
#2018
aqi_2018 = pd.DataFrame(requests.get(base_url + endpoint + "?email=" + email + "&key=" + key + "&param=" + param + "&bdate=" + "20180101" + "&edate=" + "20181231" + "&state=" + "53").json()["Data"])
# display(aqi_2018.shape)
#2019
aqi_2019 = pd.DataFrame(requests.get(base_url + endpoint + "?email=" + email + "&key=" + key + "&param=" + param + "&bdate=" + "20190101" + "&edate=" + "20191231" + "&state=" + "53").json()["Data"])
# display(aqi_2019.shape)
#2020
aqi_2020 = pd.DataFrame(requests.get(base_url + endpoint + "?email=" + email + "&key=" + key + "&param=" + param + "&bdate=" + "20200101" + "&edate=" + "20201231" + "&state=" + "53").json()["Data"])
# display(aqi_2020.shape)

# Concat Washington 2015-2020 into single DataFrame
aqi_WA_2015_2020 = pd.concat([aqi_2015, aqi_2016, aqi_2017, aqi_2018, aqi_2019, aqi_2020], axis="rows")
aqi_WA_2015_2020.reset_index(drop=True, inplace=True)
# aqi_WA_2015_2020.shape

# %%
# Show the first 5 rows and last 5 rows of the DataFrame
display(aqi_WA_2015_2020.head())
display(aqi_WA_2015_2020.tail())
# display(aqi_WA_2015_2020.shape)
# Out:
#   state_code county_code site_number parameter_code  poc   latitude  \
# 0         53         033        0080          45201    6  47.568236
# 1         53         033        0080          45201    6  47.568236
# 2         53         033        0030          45201    6  47.597222
# 3         53         033        0034          45201    6  47.600833
# 4         53         033        0035          45201    6  47.599444
#
#     longitude  datum parameter sample_duration_code  ... fiftieth_percentile  \
# 0 -122.308628  WGS84   Benzene                    7  ...                0.80
# 1 -122.308628  WGS84   Benzene                    7  ...                0.79
# 2 -122.319722  WGS84   Benzene                    7  ...                1.62
# 3 -122.314444  NAD83   Benzene                    7  ...                1.36
# 4 -122.326111  NAD83   Benzene                    7  ...                1.51
#
#   tenth_percentile        local_site_name        site_address       state  \
# ...

# %%
# Export file as a CSV, without the Pandas index, but with the header
aqi_WA_2015_2020.to_csv("Resources/aqi_WA_2015_2020.csv", index=False, header=True)

# %%
# Pull AQI for the state of New York for the Years 2015-2020
#New York = 36
#2015
aqi_2015 = pd.DataFrame(requests.get(base_url + endpoint + "?email=" + email + "&key=" + key + "&param=" + param + "&bdate=" + "20150101" + "&edate=" + "20151231" + "&state=" + "36").json()["Data"])
# display(aqi_2015.shape)
#2016
aqi_2016 = pd.DataFrame(requests.get(base_url + endpoint + "?email=" + email + "&key=" + key + "&param=" + param + "&bdate=" + "20160101" + "&edate=" + "20161231" + "&state=" + "36").json()["Data"])
# display(aqi_2016.shape)
#2017
aqi_2017 = pd.DataFrame(requests.get(base_url + endpoint + "?email=" + email + "&key=" + key + "&param=" + param + "&bdate=" + "20170101" + "&edate=" + "20171231" + "&state=" + "36").json()["Data"])
# display(aqi_2017.shape)
#2018
aqi_2018 = pd.DataFrame(requests.get(base_url + endpoint + "?email=" + email + "&key=" + key + "&param=" + param + "&bdate=" + "20180101" + "&edate=" + "20181231" + "&state=" + "36").json()["Data"])
# display(aqi_2018.shape)
#2019
aqi_2019 = pd.DataFrame(requests.get(base_url + endpoint + "?email=" + email + "&key=" + key + "&param=" + param + "&bdate=" + "20190101" + "&edate=" + "20191231" + "&state=" + "36").json()["Data"])
# display(aqi_2019.shape)
#2020
aqi_2020 = pd.DataFrame(requests.get(base_url + endpoint + "?email=" + email + "&key=" + key + "&param=" + param + "&bdate=" + "20200101" + "&edate=" + "20201231" + "&state=" + "36").json()["Data"])
# display(aqi_2020.shape)

# Concat New York 2015-2020 into single DataFrame
aqi_NY_2015_2020 = pd.concat([aqi_2015, aqi_2016, aqi_2017, aqi_2018, aqi_2019, aqi_2020], axis="rows")
aqi_NY_2015_2020.reset_index(drop=True, inplace=True)

# %%
# Show the first 5 rows and last 5 rows of the DataFrame
display(aqi_NY_2015_2020.head())
display(aqi_NY_2015_2020.tail())
# display(aqi_NY_2015_2020.shape)
# Out:
#   state_code county_code site_number parameter_code  poc   latitude  \
# 0         36         029        0005          45201    2  42.876907
# 1         36         005        0110          45201   10  40.816000
# 2         36         005        0110          45201   20  40.816000
# 3         36         005        0110          45201    2  40.816000
# 4         36         047        0118          45201    2  40.694540
#
#    longitude  datum parameter sample_duration_code  ... fiftieth_percentile  \
# 0 -78.809526  WGS84   Benzene                    7  ...                 0.9
# 1 -73.902000  WGS84   Benzene                    7  ...                 1.1
# 2 -73.902000  WGS84   Benzene                    7  ...                 1.1
# 3 -73.902000  WGS84   Benzene                    7  ...                 1.1
# 4 -73.927690  WGS84   Benzene                    7  ...                 1.3
#
#   tenth_percentile local_site_name  \
# 0              0.5         BUFFALO
# ...

# %%
# Export file as a CSV, without the Pandas index, but with the header
aqi_NY_2015_2020.to_csv("Resources/aqi_NY_2015_2020.csv", index=False, header=True)

# %%
# Pull AQI for the state of New Mexico for the Years 2015-2020
#New Mexico = 35
#2015
aqi_2015 = pd.DataFrame(requests.get(base_url + endpoint + "?email=" + email + "&key=" + key + "&param=" + param + "&bdate=" + "20150101" + "&edate=" + "20151231" + "&state=" + "35").json()["Data"])
# display(aqi_2015.shape)
#2016
aqi_2016 = pd.DataFrame(requests.get(base_url + endpoint + "?email=" + email + "&key=" + key + "&param=" + param + "&bdate=" + "20160101" + "&edate=" + "20161231" + "&state=" + "35").json()["Data"])
# display(aqi_2016.shape)
#2017
aqi_2017 = pd.DataFrame(requests.get(base_url + endpoint + "?email=" + email + "&key=" + key + "&param=" + param + "&bdate=" + "20170101" + "&edate=" + "20171231" + "&state=" + "35").json()["Data"])
# display(aqi_2017.shape)
#2018
aqi_2018 = pd.DataFrame(requests.get(base_url + endpoint + "?email=" + email + "&key=" + key + "&param=" + param + "&bdate=" + "20180101" + "&edate=" + "20181231" + "&state=" + "35").json()["Data"])
# display(aqi_2018.shape)
#2019
aqi_2019 = pd.DataFrame(requests.get(base_url + endpoint + "?email=" + email + "&key=" + key + "&param=" + param + "&bdate=" + "20190101" + "&edate=" + "20191231" + "&state=" + "35").json()["Data"])
# display(aqi_2019.shape)
#2020
aqi_2020 = pd.DataFrame(requests.get(base_url + endpoint + "?email=" + email + "&key=" + key + "&param=" + param + "&bdate=" + "20200101" + "&edate=" + "20201231" + "&state=" + "35").json()["Data"])
# display(aqi_2020.shape)


# Concat New Mexico 2015-2020 into single DataFrame
aqi_NM_2015_2020 = pd.concat([aqi_2015, aqi_2016, aqi_2017, aqi_2018, aqi_2019, aqi_2020], axis="rows")
aqi_NM_2015_2020.reset_index(drop=True, inplace=True)

# %%
# Show the first 5 rows and last 5 rows of the DataFrame
display(aqi_NM_2015_2020.head())
display(aqi_NM_2015_2020.tail())
# display(aqi_NM_2015_2020.shape)
# Out:
#   state_code county_code site_number parameter_code  poc   latitude  \
# 0         35         031        2015          45201    6  35.538747
#
#     longitude  datum parameter sample_duration_code  ... fiftieth_percentile  \
# 0 -108.596741  WGS84   Benzene                    7  ...                1.26
#
#   tenth_percentile                  local_site_name        site_address  \
# 0             0.66  Churchrock School Toxic Project  43 Challenger Road
#
#         state    county         city  cbsa_code        cbsa  \
# 0  New Mexico  McKinley  Church Rock      23700  Gallup, NM
#
#   date_of_last_change
# 0          2020-05-21
#
# [1 rows x 56 columns]
#   state_code county_code site_number parameter_code  poc   latitude  \
# 0         35         031        2015          45201    6  35.538747
#
#     longitude  datum parameter sample_duration_code  ... fiftieth_percentile  \
# 0 -108.596741  WGS84   Benzene                    7  ...                1.26
#
# ...

# %%
# Export file as a CSV, without the Pandas index, but with the header
aqi_NM_2015_2020.to_csv("Resources/aqi_NM_2015_2020.csv", index=False, header=True)

# %%
# Concat Washington, New York, and New Mexico into a single DataFrame
aqi_WA_NY_NM_2015_2020 = pd.concat([aqi_WA_2015_2020, aqi_NY_2015_2020, aqi_NM_2015_2020], axis="rows").reset_index(drop=True)
display(aqi_WA_NY_NM_2015_2020.head())
display(aqi_WA_NY_NM_2015_2020.tail())
# display(aqi_WA_NY_NM_2015_2020.shape)
# Out:
#   state_code county_code site_number parameter_code  poc   latitude  \
# 0         53         033        0080          45201    6  47.568236
# 1         53         033        0080          45201    6  47.568236
# 2         53         033        0030          45201    6  47.597222
# 3         53         033        0034          45201    6  47.600833
# 4         53         033        0035          45201    6  47.599444
#
#     longitude  datum parameter sample_duration_code  ... fiftieth_percentile  \
# 0 -122.308628  WGS84   Benzene                    7  ...                0.80
# 1 -122.308628  WGS84   Benzene                    7  ...                0.79
# 2 -122.319722  WGS84   Benzene                    7  ...                1.62
# 3 -122.314444  NAD83   Benzene                    7  ...                1.36
# 4 -122.326111  NAD83   Benzene                    7  ...                1.51
#
#   tenth_percentile        local_site_name        site_address       state  \
# ...

# %%
# Export file as a CSV, without the Pandas index, but with the header
aqi_WA_NY_NM_2015_2020.to_csv("Resources/aqi_WA_NY_NM_2015_2020.csv", index=False, header=True)

# %%
# Pull AQI for the state of Texas for the Years 2015-2020
#Texas = 48
#2015
aqi_2015 = pd.DataFrame(requests.get(base_url + endpoint + "?email=" + email + "&key=" + key + "&param=" + param + "&bdate=" + "20150101" + "&edate=" + "20151231" + "&state=" + "48").json()["Data"])
# display(aqi_2015.shape)
#2016
aqi_2016 = pd.DataFrame(requests.get(base_url + endpoint + "?email=" + email + "&key=" + key + "&param=" + param + "&bdate=" + "20160101" + "&edate=" + "20161231" + "&state=" + "48").json()["Data"])
# display(aqi_2016.shape)
#2017
aqi_2017 = pd.DataFrame(requests.get(base_url + endpoint + "?email=" + email + "&key=" + key + "&param=" + param + "&bdate=" + "20170101" + "&edate=" + "20171231" + "&state=" + "48").json()["Data"])
# display(aqi_2017.shape)
#2018
aqi_2018 = pd.DataFrame(requests.get(base_url + endpoint + "?email=" + email + "&key=" + key + "&param=" + param + "&bdate=" + "20180101" + "&edate=" + "20181231" + "&state=" + "48").json()["Data"])
# display(aqi_2018.shape)
#2019
aqi_2019 = pd.DataFrame(requests.get(base_url + endpoint + "?email=" + email + "&key=" + key + "&param=" + param + "&bdate=" + "20190101" + "&edate=" + "20191231" + "&state=" + "48").json()["Data"])
# display(aqi_2019.shape)
#2020
aqi_2020 = pd.DataFrame(requests.get(base_url + endpoint + "?email=" + email + "&key=" + key + "&param=" + param + "&bdate=" + "20200101" + "&edate=" + "20201231" + "&state=" + "48").json()["Data"])
# display(aqi_2020.shape)


# Concat Texas 2015-2020 into single DataFrame
aqi_TX_2015_2020 = pd.concat([aqi_2015, aqi_2016, aqi_2017, aqi_2018, aqi_2019, aqi_2020], axis="rows")
aqi_TX_2015_2020.reset_index(drop=True, inplace=True)

# %%
# Show the first 5 rows and last 5 rows of the DataFrame
display(aqi_TX_2015_2020.head())
display(aqi_TX_2015_2020.tail())
# display(aqi_TX_2015_2020.shape)
# Out:
#   state_code county_code site_number parameter_code  poc   latitude  \
# 0         48         245        0009          45201    6  30.036422
# 1         48         245        1035          45201    1  29.979958
# 2         48         201        1039          45201    3  29.670025
# 3         48         139        1044          45201    1  32.175417
# 4         48         113        0069          45201   10  32.820061
#
#    longitude  datum parameter sample_duration_code  ... fiftieth_percentile  \
# 0 -94.071061  WGS84   Benzene                    1  ...                0.95
# 1 -94.004746  WGS84   Benzene                    1  ...                0.82
# 2 -95.128508  WGS84   Benzene                    7  ...                1.68
# 3 -96.870189  WGS84   Benzene                    7  ...                0.84
# 4 -96.860117  WGS84   Benzene                    7  ...                1.02
#
#   tenth_percentile        local_site_name             site_address  state  \
# ...

# %%
# Export file as a CSV, without the Pandas index, but with the header
aqi_TX_2015_2020.to_csv("Resources/aqi_TX_2015_2020.csv", index=False, header=True)

# %%
# Concat Washington, New York, and Texas into a single DataFrame
aqi_WA_NY_TX_2015_2020 = pd.concat([aqi_WA_2015_2020, aqi_NY_2015_2020, aqi_TX_2015_2020], axis="rows").reset_index(drop=True)
display(aqi_WA_NY_TX_2015_2020.head())
display(aqi_WA_NY_TX_2015_2020.tail())
# display(aqi_WA_NY_TX_2015_2020.shape)
# Out:
#   state_code county_code site_number parameter_code  poc   latitude  \
# 0         53         033        0080          45201    6  47.568236
# 1         53         033        0080          45201    6  47.568236
# 2         53         033        0030          45201    6  47.597222
# 3         53         033        0034          45201    6  47.600833
# 4         53         033        0035          45201    6  47.599444
#
#     longitude  datum parameter sample_duration_code  ... fiftieth_percentile  \
# 0 -122.308628  WGS84   Benzene                    7  ...                0.80
# 1 -122.308628  WGS84   Benzene                    7  ...                0.79
# 2 -122.319722  WGS84   Benzene                    7  ...                1.62
# 3 -122.314444  NAD83   Benzene                    7  ...                1.36
# 4 -122.326111  NAD83   Benzene                    7  ...                1.51
#
#   tenth_percentile        local_site_name        site_address       state  \
# ...

# %%
# Export file as a CSV, without the Pandas index, but with the header
aqi_WA_NY_TX_2015_2020.to_csv("Resources/aqi_WA_NY_TX_2015_2020.csv", index=False, header=True)
