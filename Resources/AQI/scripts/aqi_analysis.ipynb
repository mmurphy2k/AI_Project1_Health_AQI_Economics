# %% [markdown]
# #### Import Libraries and Dependencies

# %%
import pandas as pd
from pathlib import Path

# %% [markdown]
# #### Read in Files

# %%
# Read in data
aq1_2015 = pd.read_csv('Resources/AQI/source/2015.csv')
aq1_2016 = pd.read_csv('Resources/AQI/source/2016.csv')
aq1_2017 = pd.read_csv('Resources/AQI/source/2017.csv')
aq1_2018 = pd.read_csv('Resources/AQI/source/2018.csv')
aq1_2019 = pd.read_csv('Resources/AQI/source/2019.csv')
aq1_2020 = pd.read_csv('Resources/AQI/source/2020.csv')

# %%
# Join by rows axis
aq1_2015_2020 = pd.concat([aq1_2015, aq1_2016, aq1_2017, aq1_2018, aq1_2019, aq1_2020], axis="rows").dropna()
aq1_2015_2020.head()
# Out:
#      State   County  Year  Days with AQI  Good Days  Moderate Days  \
# 0  Alabama  Baldwin  2015            264        205             58
# 1  Alabama     Clay  2015            112         73             39
# 2  Alabama  Colbert  2015            280        221             59
# 3  Alabama   DeKalb  2015            363        294             68
# 4  Alabama   Elmore  2015            233        223              9
#
#    Unhealthy for Sensitive Groups Days  Unhealthy Days  Very Unhealthy Days  \
# 0                                    1               0                    0
# 1                                    0               0                    0
# 2                                    0               0                    0
# 3                                    1               0                    0
# 4                                    1               0                    0
#
#    Hazardous Days  Max AQI  90th Percentile AQI  Median AQI  Days CO  \
# ...

# %%
#Export file
#aq1_2015_2020.to_csv("Output/annual_aqi_2015_2020.csv", index=False, header=True)
